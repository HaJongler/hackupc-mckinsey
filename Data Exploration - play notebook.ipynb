# %%
import pandas as pd
from sklearn.metrics import f1_score
import seaborn as sns

# %%
df_accidents = pd.read_csv('accidents.csv')

# %%
df_accidents.head()
# Out:
#    accident_id  location_easting_osgr  location_northing_osgr  longitude  \
# 0       359433               519310.0                188730.0  -0.279323
# 1       446617               551920.0                174560.0   0.184928
# 2       342312               505930.0                183850.0  -0.473837
# 3       495118               527770.0                168930.0  -0.164442
# 4       595500               510740.0                177230.0  -0.406580
#
#     latitude  number_of_vehicles  number_of_casualties        date   time  \
# 0  51.584754                   2                     1  2016-01-11  02:30
# 1  51.449595                   1                     1  2016-01-11  00:37
# 2  51.543563                   1                     1  2016-01-11  01:25
# 3  51.404958                   1                     1  2016-01-11  09:15
# 4  51.483139                   2                     1  2016-01-11  07:53
#
#   1st_road_class  ...  weather_conditions  road_surface_conditions  \
# ...

# %%
df_accidents.special_conditions_at_site.value_counts()
# Out:
# None                                          134231
# Roadworks                                       1437
# -1                                               506
# Mud                                              324
# Oil or diesel                                    309
# Road surface defective                           303
# Auto traffic signal - out                        285
# Road sign or marking defective or obscured       156
# Auto signal part defective                        48
# Name: special_conditions_at_site, dtype: int64

# %%
df_plot= df_accidents.groupby(['target', 'road_surface_conditions']).size().reset_index().pivot(columns='target', index='road_surface_conditions', values=0)
df_plot.plot(kind='bar', stacked=True)

# %%
pd.value_counts(df_accidents['target']).plot.bar()

# %%
df_severe = df_accidents[df_accidents.target==0]
df_severe.head()
# Out:
#    accident_id  location_easting_osgr  location_northing_osgr  longitude  \
# 0       359433               519310.0                188730.0  -0.279323
# 1       446617               551920.0                174560.0   0.184928
# 2       342312               505930.0                183850.0  -0.473837
# 3       495118               527770.0                168930.0  -0.164442
# 4       595500               510740.0                177230.0  -0.406580
#
#     latitude  number_of_vehicles  number_of_casualties        date   time  \
# 0  51.584754                   2                     1  2016-01-11  02:30
# 1  51.449595                   1                     1  2016-01-11  00:37
# 2  51.543563                   1                     1  2016-01-11  01:25
# 3  51.404958                   1                     1  2016-01-11  09:15
# 4  51.483139                   2                     1  2016-01-11  07:53
#
#   1st_road_class  ...  weather_conditions  road_surface_conditions  \
# ...

# %%
pd.value_counts(df_severe['weather_conditions']).plot.bar()

# %%
pd.value_counts(df_severe['road_surface_conditions']).plot.bar()

# %%
pd.value_counts(df_severe['special_conditions_at_site']).plot.bar()

# %%
pd.value_counts(df_severe['carriageway_hazards']).plot.bar()

# %%
pd.value_counts(df_severe['urban_or_rural_area']).plot.bar()

# %%
pd.value_counts(df_severe['1st_road_class']).plot.bar()

# %%
pd.value_counts(df_severe['local_authority_district']).plot.bar()

# %%
df_class_0 = df_train[df_train['target'] == 0]
df_class_1 = df_train[df_train['target'] == 1]
